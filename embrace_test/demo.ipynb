# %%
#脚本：pdf_to_txt
import os
import fitz  # PyMuPDF
from pathlib import Path

def convert_pdf_to_txt(src_folder, dst_folder):
    # 确保目标文件夹存在，如果不存在则创建
    Path(dst_folder).mkdir(parents=True, exist_ok=True)

    # 获取源文件夹下的所有 PDF 文件
    pdf_files = [f for f in os.listdir(src_folder) if f.endswith('.pdf')]

    # 遍历所有 PDF 文件
    for pdf_file in pdf_files:
        # 构建完整的源文件路径
        src_path = os.path.join(src_folder, pdf_file)
        
        # 构建目标文件路径，文件名保持不变，扩展名为 .txt
        txt_file = os.path.splitext(pdf_file)[0] + '.txt'
        dst_path = os.path.join(dst_folder, txt_file)

        # 打开 PDF 文件
        pdf_document = fitz.open(src_path)
        
        # 提取文本内容
        text = ""
        for page_num in range(pdf_document.page_count):
            page = pdf_document.load_page(page_num)
            text += page.get_text()

        # 将提取的文本内容写入目标 TXT 文件
        with open(dst_path, 'w', encoding='utf-8') as txt_file:
            txt_file.write(text)
        
        print(f"Converted {pdf_file} to {txt_file}")

if __name__ == "__main__":
    # 自定义源文件夹路径和目标文件夹路径，这里需要换成你本地的《近5年高考数学全国1-2卷（已过滤图片题）》文件夹地址
    src_folder = "/mnt/c/Users/weiyantao/Desktop/解问题/HighSchoolMathRAG/近5年高考数学全国1-2卷（已过滤图片题）"  # 替换为你的源文件夹路径
    dst_folder = "/mnt/c/Users/weiyantao/Desktop/解问题/HighSchoolMathRAG/近5年高考数学全国1-2卷（已过滤图片题）"  # 替换为你的目标文件夹路径

    # 调用转换函数
    convert_pdf_to_txt(src_folder, dst_folder)

# %%
from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings
from langchain.vectorstores import FAISS
from llama_index.embeddings import LangchainEmbedding
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredFileLoader
from langchain.document_transformers import LongContextReorder
from langchain_core.runnables import RunnableLambda
from langchain_core.runnables.passthrough import RunnableAssign
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from faiss import IndexFlatL2
from langchain_community.docstore.in_memory import InMemoryDocstore

import gradio as gr
from functools import partial
from operator import itemgetter
import os
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings
#       2 from langchain.vectorstores import FAISS
# ----> 3 from llama_index.embeddings import LangchainEmbedding
#       4 from langchain_nvidia_ai_endpoints import ChatNVIDIA
#       5 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/__init__.py:21
#      17 from llama_index.embeddings import OpenAIEmbedding
#      19 # indices
#      20 # loading
# ---> 21 from llama_index.indices import (
#      22     ComposableGraph,
#      23     DocumentSummaryIndex,
#      24     GPTDocumentSummaryIndex,
#      25     GPTKeywordTableIndex,
#      26     GPTKnowledgeGraphIndex,
#      27     GPTListIndex,
#      28     GPTRAKEKeywordTableIndex,
#      29     GPTSimpleKeywordTableIndex,
#      30     GPTTreeIndex,
#      31     GPTVectorStoreIndex,
#      32     KeywordTableIndex,
#      33     KnowledgeGraphIndex,
#      34     ListIndex,
#      35     RAKEKeywordTableIndex,
#      36     SimpleKeywordTableIndex,
#      37     SummaryIndex,
#      38     TreeIndex,
#      39     VectorStoreIndex,
#      40     load_graph_from_storage,
#      41     load_index_from_storage,
#      42     load_indices_from_storage,
#      43 )
#      45 # structured
#      46 from llama_index.indices.common.struct_store.base import SQLDocumentContextBuilder
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/indices/__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ----> 4 from llama_index.indices.composability.graph import ComposableGraph
#       5 from llama_index.indices.document_summary import (
#       6     DocumentSummaryIndex,
#       7     GPTDocumentSummaryIndex,
#       8 )
#       9 from llama_index.indices.document_summary.base import DocumentSummaryIndex
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/indices/composability/__init__.py:4
#       1 """This module contains all classes used for composing graphs over indices."""
# ----> 4 from llama_index.indices.composability.graph import ComposableGraph
#       6 __all__ = ["ComposableGraph"]
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/indices/composability/graph.py:7
#       5 from llama_index.core import BaseQueryEngine
#       6 from llama_index.data_structs.data_structs import IndexStruct
# ----> 7 from llama_index.indices.base import BaseIndex
#       8 from llama_index.schema import IndexNode, NodeRelationship, ObjectType, RelatedNodeInfo
#       9 from llama_index.service_context import ServiceContext
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/indices/base.py:6
#       3 from abc import ABC, abstractmethod
#       4 from typing import Any, Dict, Generic, List, Optional, Sequence, Type, TypeVar, cast
# ----> 6 from llama_index.chat_engine.types import BaseChatEngine, ChatMode
#       7 from llama_index.core import BaseQueryEngine, BaseRetriever
#       8 from llama_index.data_structs.data_structs import IndexStruct
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/chat_engine/__init__.py:1
# ----> 1 from llama_index.chat_engine.condense_plus_context import CondensePlusContextChatEngine
#       2 from llama_index.chat_engine.condense_question import CondenseQuestionChatEngine
#       3 from llama_index.chat_engine.context import ContextChatEngine
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/chat_engine/condense_plus_context.py:7
#       4 from typing import Any, List, Optional, Tuple
#       6 from llama_index.callbacks import CallbackManager, trace_method
# ----> 7 from llama_index.chat_engine.types import (
#       8     AgentChatResponse,
#       9     BaseChatEngine,
#      10     StreamingAgentChatResponse,
#      11     ToolOutput,
#      12 )
#      13 from llama_index.indices.base_retriever import BaseRetriever
#      14 from llama_index.indices.query.schema import QueryBundle
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/chat_engine/types.py:14
#      12 from llama_index.response.schema import Response, StreamingResponse
#      13 from llama_index.schema import NodeWithScore
# ---> 14 from llama_index.tools import ToolOutput
#      16 logger = logging.getLogger(__name__)
#      17 logger.setLevel(logging.WARNING)
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/tools/__init__.py:6
#       4 from llama_index.tools.function_tool import FunctionTool
#       5 from llama_index.tools.query_engine import QueryEngineTool
# ----> 6 from llama_index.tools.query_plan import QueryPlanTool
#       7 from llama_index.tools.retriever_tool import RetrieverTool
#       8 from llama_index.tools.types import (
#       9     AsyncBaseTool,
#      10     BaseTool,
#    (...)
#      13     adapt_to_async_tool,
#      14 )
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/tools/query_plan.py:6
#       3 from typing import Any, Dict, List, Optional
#       5 from llama_index.bridge.pydantic import BaseModel, Field
# ----> 6 from llama_index.response_synthesizers import BaseSynthesizer, get_response_synthesizer
#       7 from llama_index.schema import NodeWithScore, TextNode
#       8 from llama_index.tools.types import BaseTool, ToolMetadata, ToolOutput
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/response_synthesizers/__init__.py:5
#       3 from llama_index.response_synthesizers.accumulate import Accumulate
#       4 from llama_index.response_synthesizers.base import BaseSynthesizer
# ----> 5 from llama_index.response_synthesizers.compact_and_refine import CompactAndRefine
#       6 from llama_index.response_synthesizers.factory import get_response_synthesizer
#       7 from llama_index.response_synthesizers.generation import Generation
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/response_synthesizers/compact_and_refine.py:4
#       1 from typing import Any, List, Optional, Sequence
#       3 from llama_index.prompts.prompt_utils import get_biggest_prompt
# ----> 4 from llama_index.response_synthesizers.refine import Refine
#       5 from llama_index.types import RESPONSE_TEXT_TYPE
#       8 class CompactAndRefine(Refine):
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/response_synthesizers/refine.py:5
#       2 from typing import Any, Callable, Generator, Optional, Sequence, Type, cast
#       4 from llama_index.bridge.pydantic import BaseModel, Field, ValidationError
# ----> 5 from llama_index.indices.utils import truncate_text
#       6 from llama_index.llm_predictor.base import LLMPredictorType
#       7 from llama_index.prompts.base import BasePromptTemplate, PromptTemplate
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/indices/utils.py:10
#       8 from llama_index.schema import BaseNode, ImageNode, MetadataMode
#       9 from llama_index.utils import globals_helper, truncate_text
# ---> 10 from llama_index.vector_stores.types import VectorStoreQueryResult
#      12 _logger = logging.getLogger(__name__)
#      15 def get_sorted_node_list(node_dict: Dict[int, BaseNode]) -> List[BaseNode]:
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/vector_stores/__init__.py:24
#      22 from llama_index.vector_stores.faiss import FaissVectorStore
#      23 from llama_index.vector_stores.lancedb import LanceDBVectorStore
# ---> 24 from llama_index.vector_stores.lantern import LanternVectorStore
#      25 from llama_index.vector_stores.metal import MetalVectorStore
#      26 from llama_index.vector_stores.milvus import MilvusVectorStore
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/vector_stores/lantern.py:120
#     105     Index(
#     106         hnsw_indexname,
#     107         model.embedding,  # type: ignore
#    (...)
#     115         postgresql_ops={"embedding": "dist_cos_ops"},
#     116     )
#     117     return model
# --> 120 class LanternVectorStore(BasePydanticVectorStore):
#     121     from sqlalchemy.sql.selectable import Select
#     123     stores_text = True
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/llama_index/vector_stores/lantern.py:121, in LanternVectorStore()
#     120 class LanternVectorStore(BasePydanticVectorStore):
# --> 121     from sqlalchemy.sql.selectable import Select
#     123     stores_text = True
#     124     flat_metadata = False
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/sqlalchemy/__init__.py:12
#       8 from __future__ import annotations
#      10 from typing import Any
# ---> 12 from . import util as _util
#      13 from .engine import AdaptedConnection as AdaptedConnection
#      14 from .engine import BaseRow as BaseRow
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/sqlalchemy/util/__init__.py:15
#      12 from typing import TYPE_CHECKING
#      14 from . import preloaded as preloaded
# ---> 15 from ._collections import coerce_generator_arg as coerce_generator_arg
#      16 from ._collections import coerce_to_immutabledict as coerce_to_immutabledict
#      17 from ._collections import column_dict as column_dict
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/sqlalchemy/util/_collections.py:37
#      34 from typing import ValuesView
#      35 import weakref
# ---> 37 from ._has_cy import HAS_CYEXTENSION
#      38 from .typing import is_non_string_iterable
#      39 from .typing import Literal
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/sqlalchemy/util/_has_cy.py:32
#      30 else:
#      31     try:
# ---> 32         _import_cy_extensions()
#      33     except ImportError as err:
#      34         HAS_CYEXTENSION = False
#
# File ~/miniconda3/envs/nvidia/lib/python3.9/site-packages/sqlalchemy/util/_has_cy.py:19, in _import_cy_extensions()
#      17 from ..cyextension import immutabledict
#      18 from ..cyextension import processors
# ---> 19 from ..cyextension import resultproxy
#      20 from ..cyextension import util
#      22 return (collections, immutabledict, processors, resultproxy, util)
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:

# %%
import os
#这里的api_key也可以换成其他模型的，可以找一个更匹配咱们做的东西的模型
nvidia_api_key = "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"
assert nvidia_api_key.startswith("nvapi-"), f"{nvidia_api_key[:5]}... is not a valid key"
os.environ["NVIDIA_API_KEY"] = nvidia_api_key

# %%
llm = ChatNVIDIA(model="ai-nemotron-4-340b-instruct")
result = llm.invoke("what is nemo")
print(result.content)
# Out:
# Nemo is a character from the animated film "Finding Nemo," produced by Pixar Animation Studios and released by Walt Disney Pictures in 2003. Nemo is a young clownfish who gets separated from his father, Marlin, and ends up in a fish tank in a dentist's office in Sydney, Australia. The movie follows Marlin's journey to find and rescue Nemo, with the help of a forgetful blue tang fish named Dory. Nemo is a curious, adventurous, and determined character who learns important lessons about trust, independence, and the importance of family throughout the film.

# %%
embedder = NVIDIAEmbeddings(model="ai-embed-qa-4")
embedder.embed_query("test")
# Out:
# [-0.0193023681640625,
#  -0.0175018310546875,
#  -0.03448486328125,
#  -0.00595855712890625,
#  0.03192138671875,
#  0.046142578125,
#  0.0007371902465820312,
#  -0.01788330078125,
#  0.0220184326171875,
#  0.004657745361328125,
#  0.087158203125,
#  0.0168914794921875,
#  0.02239990234375,
#  -0.039398193359375,
#  0.0133819580078125,
#  0.02166748046875,
#  -0.0005540847778320312,
#  -0.019439697265625,
#  -0.0280303955078125,
#  0.0257110595703125,
#  0.0145416259765625,
#  0.001117706298828125,
#  0.051910400390625,
#  -0.0037689208984375,
#  0.017974853515625,
#  0.0166778564453125,
#  -0.01446533203125,
#  -0.034820556640625,
#  0.03497314453125,
#  0.061920166015625,
#  -0.03436279296875,
#  -0.0911865234375,
#  0.0003790855407714844,
#  0.00490570068359375,
#  0.01529693603515625,
#  -0.04266357421875,
#  0.0423583984375,
#  0.01262664794921875,
#  -0.034820556640625,
#  0.0012845993041992188,
#  0.009063720703125,
#  -0.0202789306640625,
#  -0.002628326416015625,
#  0.01959228515625,
#  -0.022857666015625,
#  0.0033321380615234375,
#  -0.00600433349609375,
#  -0.007289886474609375,
#  0.0027980804443359375,
#  -0.040435791015625,
#  0.0433349609375,
#  -0.00870513916015625,
#  0.03472900390625,
#  -0.0019626617431640625,
#  -0.01505279541015625,
#  0.010345458984375,
#  0.104736328125,
#  0.0660400390625,
#  -0.07073974609375,
#  -0.036041259765625,
#  0.004619598388671875,
#  -0.10211181640625,
#  0.0170440673828125,
#  0.023162841796875,
#  -0.0382080078125,
#  0.04833984375,
#  -0.041748046875,
#  0.03851318359375,
#  -0.01318359375,
#  -0.01436614990234375,
#  -0.0012359619140625,
#  0.0255279541015625,
#  0.005870819091796875,
#  -0.0265350341796875,
#  -0.021575927734375,
#  -0.04730224609375,
#  0.0157012939453125,
#  -0.00904083251953125,
#  0.03851318359375,
#  0.0460205078125,
#  0.049560546875,
#  0.04595947265625,
#  -0.006702423095703125,
#  0.00720977783203125,
#  0.023681640625,
#  -0.047119140625,
#  0.061004638671875,
#  -0.0186004638671875,
#  0.034423828125,
#  0.049896240234375,
#  -0.028778076171875,
#  -0.0151519775390625,
#  0.00102996826171875,
#  -0.0196075439453125,
#  0.03216552734375,
#  0.032318115234375,
#  0.025726318359375,
#  -0.0172119140625,
#  -0.005588531494140625,
#  -0.0067596435546875,
#  ...]

# %%
import os
from tqdm import tqdm
from pathlib import Path

#读取并预处理文本数据，存储在 documents 和 sources 列表中

#这里需要换成你本地的《近5年高考数学全国1-2卷（已过滤图片题）》文件夹地址
src_folder = "/mnt/c/Users/weiyantao/Desktop/解问题/HighSchoolMathRAG/近5年高考数学全国1-2卷（已过滤图片题）"
ps = os.listdir(src_folder)
data = []
sources = []
docs_name = []
for p in ps:
    if p.endswith('.txt'):
        path2file = os.path.join(src_folder, p)
        docs_name.append(path2file)
        with open(path2file, encoding="utf-8") as f:
            lines = f.readlines()
            for line in lines:
                if len(line) >= 1:
                    data.append(line)
                    sources.append(path2file)

documents = [d for d in data if d != '\n']
print(len(data), len(documents), data[0])
# Out:
# 34441 34441 2020 年全国统一高考数学试卷（理科）（新课标Ⅰ）

# %%
from operator import itemgetter
from langchain.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain.text_splitter import CharacterTextSplitter
from langchain_nvidia_ai_endpoints import ChatNVIDIA
import faiss
# create my own uuid
text_splitter = CharacterTextSplitter(chunk_size=400, separator=" ")
docs = []
metadatas = []

# %%
for i, d in enumerate(documents):
    splits = text_splitter.split_text(d)
    #print(len(splits))
    docs.extend(splits)
    metadatas.extend([{"source": sources[i]}] * len(splits))
### 将创建好的embed存储到本地
store = FAISS.from_texts(docs, embedder , metadatas=metadatas)
store.save_local('./embed')

# %%
### 从本地读取已经创建好的embed
#这里需要换成你本地的embed文件夹地址，如果成功加载，后面的代码就可以直接运行了
vecstores = [FAISS.load_local(folder_path="/mnt/c/Users/weiyantao/Desktop/解问题/HighSchoolMathRAG/test/embed", embeddings=embedder)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 ### 从本地读取已经创建好的embed
# ----> 2 vecstores = [FAISS.load_local(folder_path="/mnt/c/Users/weiyantao/Desktop/解问题/HighSchoolMathRAG/test/embed", embeddings=embedder)]
#
# NameError: name 'FAISS' is not defined

# %%
embed_dims = len(embedder.embed_query("test"))
def default_FAISS():
    '''Useful utility for making an empty FAISS vectorstore'''
    return FAISS(
        embedding_function=embedder,
        index=IndexFlatL2(embed_dims),
        docstore=InMemoryDocstore(),
        index_to_docstore_id={},
        normalize_L2=False
    )

def aggregate_vstores(vectorstores):
    ## 初始化一个空的 FAISS 索引并将其他索引合并到其中
    agg_vstore = default_FAISS()
    for vstore in vectorstores:
        agg_vstore.merge_from(vstore)
    return agg_vstore

if 'docstore' not in globals():
    docstore = aggregate_vstores(vecstores)

print(f"Constructed aggregate docstore with {len(docstore.docstore._dict)} chunks")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 embed_dims = len(embedder.embed_query("test"))
#       2 def default_FAISS():
#       3     '''Useful utility for making an empty FAISS vectorstore'''
#
# NameError: name 'embedder' is not defined

# %%
llm = ChatNVIDIA(model="ai-nemotron-4-340b-instruct") | StrOutputParser()
convstore = default_FAISS()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 llm = ChatNVIDIA(model="ai-nemotron-4-340b-instruct") | StrOutputParser()
#       2 convstore = default_FAISS()
#
# NameError: name 'ChatNVIDIA' is not defined

# %%
doc_names_string = "\n"
for doc_name in docs_name:
    doc_names_string += doc_name+"\n"
    
def save_memory_and_get_output(d, vstore):
    """Accepts 'input'/'output' dictionary and saves to convstore"""
    vstore.add_texts([
        f"User previously responded with {d.get('input')}",
        f"Agent previously responded with {d.get('output')}"
    ])
    return d.get('output')

initial_msg = (
    "Hello! I am a document chat agent here to help the user!"
    f" I have access to the following documents: {doc_names_string}\n\nHow can I help you?"
)

chat_prompt = ChatPromptTemplate.from_messages([("system",
    "You are a document chatbot. Help the user as they ask questions about documents."
    " User messaged just asked: {input}\n\n"
    " From this, we have retrieved the following potentially-useful info: "
    " Conversation History Retrieval:\n{history}\n\n"
    " Document Retrieval:\n{context}\n\n"
    " (Answer only from retrieval. Only cite sources that are used. Make your response conversational.Reply must more than 100 words)"
), ('user', '{input}')])

## Utility Runnables/Methods
def RPrint(preface=""):
    """Simple passthrough "prints, then returns" chain"""
    def print_and_return(x, preface):
        print(f"{preface}{x}")
        return x
    return RunnableLambda(partial(print_and_return, preface=preface))

def docs2str(docs, title="Document"):
    """Useful utility for making chunks into context string. Optional, but useful"""
    out_str = ""
    for doc in docs:
        doc_name = getattr(doc, 'metadata', {}).get('Title', title)
        if doc_name:
            out_str += f"[Quote from {doc_name}] "
        out_str += getattr(doc, 'page_content', str(doc)) + "\n"
    return out_str

## 将较长的文档重新排序到输出文本的中心， RunnableLambda在链中运行无参自定义函数 ，长上下文重排序（LongContextReorder）
long_reorder = RunnableLambda(LongContextReorder().transform_documents)

retrieval_chain = (
    {'input' : (lambda x: x)}
    | RunnableAssign({'history' : itemgetter('input') | convstore.as_retriever() | long_reorder | docs2str})
    | RunnableAssign({'context' : itemgetter('input') | docstore.as_retriever()  | long_reorder | docs2str})
    | RPrint()
)
stream_chain = chat_prompt | llm

def chat_gen(message, history=[], return_buffer=True):
    buffer = ""
    ##首先根据输入的消息进行检索
    retrieval = retrieval_chain.invoke(message)
    line_buffer = ""

    ## 然后流式传输stream_chain的结果
    for token in stream_chain.stream(retrieval):
        buffer += token
        ## 优化信息打印的格式
        if not return_buffer:
            line_buffer += token
            if "\n" in line_buffer:
                line_buffer = ""
            if ((len(line_buffer)>84 and token and token[0] == " ") or len(line_buffer)>100):
                line_buffer = ""
                yield "\n"
                token = "  " + token.lstrip()
        yield buffer if return_buffer else token

    ##最后将聊天内容保存到对话内存缓冲区中
    save_memory_and_get_output({'input':  message, 'output': buffer}, convstore)

# %%
chatbot = gr.Chatbot(value = [[None, initial_msg]])
demo = gr.ChatInterface(chat_gen, chatbot=chatbot).queue()

try:
    demo.launch(debug=True, share=False, show_api=False, server_port=5000, server_name="0.0.0.0")
    demo.close()
except Exception as e:
    demo.close()
    print(e)
    raise e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 chatbot = gr.Chatbot(value = [[None, initial_msg]])
#       2 demo = gr.ChatInterface(chat_gen, chatbot=chatbot).queue()
#       4 try:
#
# NameError: name 'gr' is not defined
